# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\ML\framingham.csv")
data.head(3)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0

# %% [raw]
# Question (1):Go to framingum.csv and Take those People who are Male and  his education level is 3 and Heart Rate is grater than 65.
# Question (2):Repeat the Question 1 for Female

# %%
data1 = data.query("male==0 and education == 3 and heartRate > 65")
data1.head()
# Out:
#     male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 4      0   46        3.0              1        23.0     0.0                0
# 23     0   52        3.0              1        20.0     0.0                0
# 28     0   61        3.0              0         0.0     0.0                0
# 44     0   53        3.0              0         0.0     1.0                0
# 77     0   44        3.0              1        20.0     NaN                0
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 4              0         0    285.0  130.0   84.0  23.10       85.0     85.0
# 23             0         0    215.0  132.0   82.0  25.11       71.0     75.0
# 28             1         0    272.0  182.0  121.0  32.80       85.0     65.0
# 44             1         1    311.0  206.0   92.0  21.51       76.0    215.0
# 77             0         0    213.0  115.0   72.5  21.16       80.0     89.0
#
#     TenYearCHD
# 4            0
# ...

# %%
data2 = data.query("male==1 and education == 3 and heartRate > 65")
data2.head()
# Out:
#      male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 39      1   36        3.0              0         0.0     0.0                0
# 49      1   36        3.0              1        20.0     NaN                0
# 111     1   51        3.0              0         0.0     0.0                0
# 119     1   50        3.0              1        40.0     0.0                0
# 122     1   66        3.0              0         0.0     0.0                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 39              0         0    180.0  111.0   73.0  27.78       71.0     80.0
# 49              1         0    194.0  139.0   93.0  24.33       80.0     62.0
# 111             1         0    214.0  145.0   92.5  26.09       70.0      NaN
# 119             1         0    175.0  157.0   88.0  25.09       88.0     85.0
# 122             0         0    288.0  109.0   71.0  29.29       80.0     80.0
#
#      TenYearCHD
# ...

# %% [raw]
# Question (3) Write group by for making male as index and citrate per day in values for mean analysis

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data.groupby(["male"])[["cigsPerDay"]].mean()
# Out:
#       cigsPerDay
# male
# 0       5.729730
# 1      13.368771

# %% [raw]
# Question (4) Repeat the Question 3 for Pivot

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
import numpy as np

# %%
pd.pivot_table(data,values=["cigsPerDay"],index=["male"],aggfunc=[np.mean])
# Out:
#            mean
#      cigsPerDay
# male
# 0      5.729730
# 1     13.368771

# %% [raw]
# Question (5) Create 2 csv file one contain only male and other contain only female

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data_male = data.query("male==1")
data_male.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
#
#    TenYearCHD
# 0           0
# 2           0

# %%
data_male.to_csv("data_male.csv")

# %%
data_female = data.query("male==0")
data_female.head(3)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 1     0   46        2.0              0         0.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 1           0
# 3           1
# 4           0

# %%
data_female.to_csv("data_female.csv")

# %% [raw]
# Question (6) Create 2 csv file one contain only male and other contain only female with education level 3

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data3 = data.query("male==1 and education ==3")
data3.head(3)
# Out:
#     male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 16     1   48        3.0              1        10.0     0.0                0
# 39     1   36        3.0              0         0.0     0.0                0
# 49     1   36        3.0              1        20.0     NaN                0
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 16             1         0    232.0  138.0   90.0  22.37       64.0     72.0
# 39             0         0    180.0  111.0   73.0  27.78       71.0     80.0
# 49             1         0    194.0  139.0   93.0  24.33       80.0     62.0
#
#     TenYearCHD
# 16           0
# 39           0
# 49           0

# %%
data3.to_csv("data3.csv")

# %%
data4 = data.query("male==0 and education ==3")
data4.head(3)
# Out:
#     male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 3      0   61        3.0              1        30.0     0.0                0
# 4      0   46        3.0              1        23.0     0.0                0
# 13     0   41        3.0              0         0.0     1.0                0
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 3              1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4              0         0    285.0  130.0   84.0  23.10       85.0     85.0
# 13             1         0    332.0  124.0   88.0  31.31       65.0     84.0
#
#     TenYearCHD
# 3            1
# 4            0
# 13           0

# %%
data4.to_csv("data4.csv")
