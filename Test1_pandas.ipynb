# %% [raw]
# # Question (1):Go to framingum.csv and Take those People who are Male and  his education level is 3
#     and Heart Rate is grater than 65.

# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:\ML\framingham.csv')

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data_male = data.query("male==1")
data_male.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
#
#    TenYearCHD
# 0           0
# 2           0

# %%
data_edu = data.query("education==3")
data_edu
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 13       0   41        3.0              0         0.0     1.0
# 16       1   48        3.0              1        10.0     0.0
# 23       0   52        3.0              1        20.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4229     0   51        3.0              1        20.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3                   0             1         0    225.0  150.0   95.0  28.58
# ...

# %%
data1 = data_edu.query("heartRate>65")
data1
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4        0   46        3.0              1        23.0     0.0
# 23       0   52        3.0              1        20.0     0.0
# 28       0   61        3.0              0         0.0     0.0
# 39       1   36        3.0              0         0.0     0.0
# 44       0   53        3.0              0         0.0     1.0
# ...    ...  ...        ...            ...         ...     ...
# 4222     1   53        3.0              0         0.0     0.0
# 4229     0   51        3.0              1        20.0     0.0
# 4231     1   58        3.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...

# %%
data_male.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
#
#    TenYearCHD
# 0           0
# 2           0

# %% [raw]
# Question (1):Repeat the Question 1 for Female

# %%
data_female = data.query("male==0")
data_female.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 1     0   46        2.0              0         0.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
#
#    TenYearCHD
# 1           0
# 3           1

# %%
data_female_edu = data_female.query("education==3")
data_female_edu.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 3           1
# 4           0

# %%
data2 = data_female_edu.query("heartRate>65")
data2.head(2)
# Out:
#     male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 4      0   46        3.0              1        23.0     0.0                0
# 23     0   52        3.0              1        20.0     0.0                0
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 4              0         0    285.0  130.0   84.0  23.10       85.0     85.0
# 23             0         0    215.0  132.0   82.0  25.11       71.0     75.0
#
#     TenYearCHD
# 4            0
# 23           0

# %% [raw]
# Question (3) Write group by for making male as index and citrate per day in values for mean analysis

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
import numpy as np

# %%
data.groupby(["male"])[["cigsPerDay"]].mean()
# Out:
#       cigsPerDay
# male
# 0       5.729730
# 1      13.368771

# %% [raw]
# Question (4) Repeat the Question 3 for Pivot : Question (3) Write pivot for making male as index and citrate per day in values for mean analysis

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
pd.pivot_table(data,values=["cigsPerDay"],index=["male"],aggfunc=[np.mean])
# Out:
#            mean
#      cigsPerDay
# male
# 0      5.729730
# 1     13.368771

# %% [raw]
# Question (5) Create 2 csv file one contain only male and other contain only female

# %%
data.head(2)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
#
#    TenYearCHD
# 0           0
# 1           0

# %%
data_male.to_csv("data_male.csv")

# %%
data_female.to_csv("data_female.csv")
